# %%
#loading data  with pandas
#Dependencies or labraries are pre-install to help solve problem

# %%
#pandas 
#this is a propular libraries gor data analysis
#We can import labraries or a dependency like pandas using following commands
import pandas as pd

# %%
#we now have access to alarge number pre built class & function
#We like to load "csv" file using pandas built in function, read csv file.
#"csv" file is a typical file type used for store data.
#For example
csv_path ="ex\csv.csv"
df = pd.read_csv(csv_path)

# %%
#Data frame is comprised row and column
#One way pandas allow you to work with data is with "data frame" using "head()"
#For example
df.head(100)
# Out:
#     Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0   2018                     Level 1                99999
# 1   2018                     Level 1                99999
# 2   2018                     Level 1                99999
# 3   2018                     Level 1                99999
# 4   2018                     Level 1                99999
# ..   ...                         ...                  ...
# 95  2018                     Level 4                AA111
# 96  2018                     Level 4                AA111
# 97  2018                     Level 4                AA111
# 98  2018                     Level 4                AA111
# 99  2018                     Level 4                AA111
#
#               Industry_name_NZSIOC               Units Variable_code  \
# 0                   All industries  Dollars (millions)           H01
# 1                   All industries  Dollars (millions)           H04
# ...

# %%
#Now create data frame out of a dictionary
#For example
songs = {'artist':["yuvraj","bib","r&b"],
        'released':[1960,1988,1999],
        'lenght':["0:42:12","0:25:14","1:36:14"]}
song_frame=pd.DataFrame(songs)
#df = pd.read_csv(song_frame)
song_frame.head()
# Out:
#    artist  released   lenght
# 0  yuvraj      1960  0:42:12
# 1     bib      1988  0:25:14
# 2     r&b      1999  1:36:14

# %%
#This is for single column
#For example
df = pd.read_csv(csv_path)
x=df[["Year"]]
x.head()
# Out:
#    Year
# 0  2018
# 1  2018
# 2  2018
# 3  2018
# 4  2018

# %%
#This is for multiple column
#For example
df = pd.read_csv(csv_path)
x=df[["Year","Industry_aggregation_NZSIOC","Industry_code_NZSIOC"]]
x.head(10)
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC
# 0  2018                     Level 1                99999
# 1  2018                     Level 1                99999
# 2  2018                     Level 1                99999
# 3  2018                     Level 1                99999
# 4  2018                     Level 1                99999
# 5  2018                     Level 1                99999
# 6  2018                     Level 1                99999
# 7  2018                     Level 1                99999
# 8  2018                     Level 1                99999
# 9  2018                     Level 1                99999

# %%
# And can we use similar with excel file also

# %%
import pandas as pd

# %%
xlsx_path = 'ex\hh.xlsx'
df = pd.read_excel(xlsx_path)
df.head(8)
# Out:
#                     SSS                                                url  \
# 0            10.0.10.16             http://10.0.10.16:8090/httpclient.html
# 1           192.168.1.1              http://192.168.1.1/cgi-bin/index2.asp
# 2           192.168.1.1            http://192.168.1.1/cgi-bin/net-wlan.asp
# 3     www.accenture.com  https://www.accenture.com/in-en/Careers/Regist...
# 4  acnsts.accenture.com              https://acnsts.accenture.com/adfs/ls/
# 5  wipro.altrecruit.com  https://wipro.altrecruit.com/view/job/jobDetai...
# 6  wipro.altrecruit.com  https://wipro.altrecruit.com/view/job/jobDetai...
# 7        www.amazon.com                 https://www.amazon.com/ap/register
#
#                            username
# 0                  16bcs0922762.iet
# 1                             admin
# 2                              apte
# 3             uvpatsariya@gmail.com
# 4             uvpatsariya@gmail.com
# 5            uvpatsariya@gmaial.com
# ...

# %%
#Now using "loc" function, you can use column header and row index to select data. column in name from and row in integer from.
#for example
df.loc[1,"url"]
# Out:
# 'http://192.168.1.1/cgi-bin/index2.asp'

# %%
#Now using "loc" function, you can use column header and row index to select data. column in integer from and row in integer from.
#for example
df.iloc[2,2]
# Out:
# 'apte'

# %%
#We can prefrom slicing in both "loc" and "iloc"
#For example
df.loc[0:4,"SSS":"username"]
# Out:
#                     SSS                                                url  \
# 0            10.0.10.16             http://10.0.10.16:8090/httpclient.html
# 1           192.168.1.1              http://192.168.1.1/cgi-bin/index2.asp
# 2           192.168.1.1            http://192.168.1.1/cgi-bin/net-wlan.asp
# 3     www.accenture.com  https://www.accenture.com/in-en/Careers/Regist...
# 4  acnsts.accenture.com              https://acnsts.accenture.com/adfs/ls/
#
#                 username
# 0       16bcs0922762.iet
# 1                  admin
# 2                   apte
# 3  uvpatsariya@gmail.com
# 4  uvpatsariya@gmail.com

# %%
df.iloc[0:4,0:2]
# Out:
#                  SSS                                                url
# 0         10.0.10.16             http://10.0.10.16:8090/httpclient.html
# 1        192.168.1.1              http://192.168.1.1/cgi-bin/index2.asp
# 2        192.168.1.1            http://192.168.1.1/cgi-bin/net-wlan.asp
# 3  www.accenture.com  https://www.accenture.com/in-en/Careers/Regist...

# %%
#We can use "ix" function it preform in both vise "loc vise" and "iloc vise"
